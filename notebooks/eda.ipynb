# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processed/AAWW_processed.csv')

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3602 entries, 0 to 3601
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            3602 non-null   object
#  1   Open            3602 non-null   float64
#  2   High            3602 non-null   float64
#  3   Low             3602 non-null   float64
#  4   Close           3602 non-null   float64
#  5   Adj Close       3602 non-null   float64
#  6   Volume          3602 non-null   int64
#  7   Return          3602 non-null   float64
#  8   Volatility_5d   3602 non-null   float64
#  9   Volatility_20d  3602 non-null   float64
#  10  MA_5d           3602 non-null   float64
#  11  MA_20d          3602 non-null   float64
#  12  EMA_12d         3602 non-null   float64
#  13  EMA_26d         3602 non-null   float64
#  14  MACD            3602 non-null   float64
#  15  MACD_Signal     3602 non-null   float64
#  16  RSI_14d         3602 non-null   float64
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Close'])
plt.title('AAWW Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.show()

# %%
df[['MA_5d', 'MA_20d', 'RSI_14d']].plot(subplots=True, figsize=(15,8))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)
